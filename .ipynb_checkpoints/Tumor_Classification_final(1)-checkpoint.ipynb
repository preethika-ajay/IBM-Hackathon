# %% [markdown]
# # Cerebral Carcinoma Detection Using Magnetic Resonance Imaging with Deep Learning Techniques
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# ## Importing Modules

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
import os
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

# %% [markdown]
# ## Preparing Dataset

# %%
height_ = 100
width_ = 100

# %%
# from google.colab import drive
# drive.mount('/content/drive/')

# %%
train = ImageDataGenerator(rescale=1/255, rotation_range = 0.2, brightness_range = (0.1,0.3))
test = ImageDataGenerator(rescale=1/255, rotation_range = 0.2, brightness_range = (0.1,0.3))

# %%
# cd drive/MyDrive

# %%
train_dataset = train.flow_from_directory("IBM/Train/",
                                          target_size=(width_, height_), 
                                            # color_mode='grayscale',
                                            batch_size=8,
                                            class_mode='binary')
                                         
val_dataset = test.flow_from_directory("IBM/Val/",
                                          target_size=(width_, height_),
                                            # color_mode='grayscale',
                                            batch_size=8,
                                            class_mode='binary')
# Out:
# Found 202 images belonging to 2 classes.
# Found 25 images belonging to 2 classes.

# %%
train_dataset.class_indices
# Out:
# {'No': 0, 'Yes': 1}

# %% [markdown]
# ## Preparing Model

# %%
with tf.device('/device:GPU:2'):
    SIZE_OF_IP = (width_, height_, 3) 
    model = keras.Sequential()

    # Convolutional layer and maxpool layer 1
    model.add(keras.layers.Conv2D(32,(3,3),activation='leaky_relu',input_shape=SIZE_OF_IP))
    model.add(keras.layers.MaxPool2D(2,2))

    # Convolutional layer and maxpool layer 2
    model.add(keras.layers.Conv2D(64,(3,3),activation='leaky_relu'))
    model.add(keras.layers.MaxPool2D(2,2))

    # Convolutional layer and maxpool layer 3
    model.add(keras.layers.Conv2D(128,(3,3),activation='leaky_relu'))
    model.add(keras.layers.MaxPool2D(2,2))
    model.add(keras.layers.Dropout(0.2))


    # # Convolutional layer and maxpool layer 4
    # model.add(keras.layers.Conv2D(128,(3,3),activation='relu'))
    # model.add(keras.layers.MaxPool2D(2,2))

    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(512,activation='leaky_relu'))

   # Op layer
    model.add(keras.layers.Dense(1,activation='sigmoid'))

# %% [markdown]
# ## Training

# %%
with tf.device('/device:GPU:2'):
    model.compile(optimizer='rmsprop',loss='binary_crossentropy',metrics=['accuracy'])
    history = model.fit(train_dataset,epochs = 5,validation_data = val_dataset)
# Out:
# Epoch 1/5
# 26/26 [==============================] - 5s 170ms/step - loss: 0.7326 - accuracy: 0.6386 - val_loss: 0.6857 - val_accuracy: 0.6000
# Epoch 2/5
# 26/26 [==============================] - 4s 161ms/step - loss: 0.6168 - accuracy: 0.7228 - val_loss: 0.6019 - val_accuracy: 0.8000
# Epoch 3/5
# 26/26 [==============================] - 4s 160ms/step - loss: 0.5640 - accuracy: 0.7525 - val_loss: 0.4660 - val_accuracy: 0.8400
# Epoch 4/5
# 26/26 [==============================] - 4s 159ms/step - loss: 0.4564 - accuracy: 0.7871 - val_loss: 0.4681 - val_accuracy: 0.8400
# Epoch 5/5
# 26/26 [==============================] - 4s 158ms/step - loss: 0.4796 - accuracy: 0.8465 - val_loss: 0.5081 - val_accuracy: 0.8000

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
epochs = range(len(acc))

plt.plot(epochs, acc, 'b', label='Training Accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation Accuracy')
plt.title('Accuracy Graph')
plt.legend()
plt.figure()

# %% [markdown]
# ## Saving Model

# %%
model.save("tumor_grayscale_drop.h5")

# %% [markdown]
# ## Loading Model

# %%
from keras import models

savedModel = models.load_model('tumor_grayscale_drop.h5')
savedModel.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 98, 98, 32)        896
#
#  max_pooling2d_8 (MaxPooling  (None, 49, 49, 32)       0
#  2D)
#
#  conv2d_9 (Conv2D)           (None, 47, 47, 64)        18496
#
#  max_pooling2d_9 (MaxPooling  (None, 23, 23, 64)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 21, 21, 128)       73856
#
#  max_pooling2d_10 (MaxPoolin  (None, 10, 10, 128)      0
#  g2D)
#
#  dropout (Dropout)           (None, 10, 10, 128)       0
#
#  flatten_3 (Flatten)         (None, 12800)             0
#
#  dense_6 (Dense)             (None, 512)               6554112
#
#  dense_7 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 6,647,873
# Trainable params: 6,647,873
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Inferencing

# %%
from PIL import Image, ImageOps

# %%
def make_list_of_imgs(path):
    imgs = []
    valid_images = [".jpg"]
    for f in os.listdir(path):
        ext = os.path.splitext(f)[1]
        if ext.lower() not in valid_images:
            continue
        imgs.append(path + f)
    return imgs

# %%
def tumor_prediction(*argv): 
    for arg in argv: 
        for filename in arg:
            # image_read = cv2.imread(filename)
            print(filename)
            im = Image.open(filename)
            im2 = im.convert('RGB')
            im2 = im2.resize((height_, width_))
            # print(im1.shape)
            # image_read = cv2.resize(image_read, (height_, width_))
            image = np.array(im2) 
            # image = np.reshape(image, [100, 100, 3])
            plt.show()
            plt.imshow(image)
           
            X = np.expand_dims(image,axis=0)
            result = savedModel.predict(X)
            # print(val)
            if result == 1:
                plt.xlabel("TUMOR",fontsize=15)


            elif result == 0:
                plt.xlabel("NO TUMOR",fontsize=15)

# %% [markdown]
# ### Testing on MRI images with cerebral Carcinoma

# %%
tumor_prediction(make_list_of_imgs('IBM/yes/') )
# Out:
# IBM/yes/Y257.jpg
# IBM/yes/Y246.JPG
# IBM/yes/Y244.JPG
# IBM/yes/Y258.JPG
# IBM/yes/Y255.JPG
# IBM/yes/Y252.jpg
# IBM/yes/Y250.jpg
# IBM/yes/Y253.JPG
# IBM/yes/Y245.jpg
# IBM/yes/Y247.JPG
# IBM/yes/Y256.JPG
# IBM/yes/Y248.JPG
# IBM/yes/Y249.JPG
# IBM/yes/Y254.jpg
# IBM/yes/Y251.JPG
# IBM/yes/Y259.JPG

# %% [markdown]
# Out of 15 test images, 12 were classified correctly

# %% [markdown]
# ### Testing with MRI images without cerebral carcinoma

# %%
tumor_prediction(make_list_of_imgs('IBM/no/') )#classified
# Out:
# IBM/no/No18.jpg
# IBM/no/No19.jpg
# IBM/no/No16.jpg
# IBM/no/No22.jpg
# IBM/no/No13.jpg
# IBM/no/No17.jpg
# IBM/no/No21.jpg
# IBM/no/No14.jpg
# IBM/no/No20.jpg
# IBM/no/No15.jpg

# %% [markdown]
# Out of the 10 test images, 9 were classified correctly
